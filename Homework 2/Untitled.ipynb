# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([0,1,2,3,4],[0,2,0,-2,0])
plt.xlabel("$t$")
plt.ylabel("$y_2(t)$")
plt.savefig("fig3a.png")

# %%
plt.plot([-1,0,1,2],[0,2,2,0])
plt.xlabel("$t$")
plt.ylabel("$y_3(t)$")
plt.savefig("fig3b.png")

# %%
plt.plot([-4,-2,0,1,2,3,4],[0,0,2,3,2,0,0])
plt.xlabel("$t$")
plt.ylabel("$s\{u(t+2)+u(t)-2u(t-1)\}$")
plt.savefig("fig3c.png")

# %%
plt.plot([-4,-2,-0.0001,0,1,2,2.00001,3,4],[0,0,2,4,5,4,2,0,0])
plt.xlabel("$t$")
plt.ylabel("$s\{x(t)\}$")
plt.savefig("fig3c2.png")
